# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e857a04f-3894-43f6-9d06-3605b8c80c78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e857a04f-3894-43f6-9d06-3605b8c80c78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving img_2.jpg to img_2.jpg

# %%
img = cv2.imread('img_2.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[ 77,  71,  66],
#         [ 77,  71,  66],
#         [ 78,  72,  67],
#         ...,
#         [ 32,  49,  52],
#         [ 32,  49,  52],
#         [ 32,  49,  52]],
#
#        [[ 77,  71,  66],
#         [ 77,  71,  66],
#         [ 78,  72,  67],
#         ...,
#         [ 32,  49,  52],
#         [ 32,  49,  52],
#         [ 32,  49,  52]],
#
#        [[ 77,  71,  66],
#         [ 77,  71,  66],
#         [ 78,  72,  67],
#         ...,
#         [ 32,  49,  52],
#         [ 32,  49,  52],
#         [ 32,  49,  52]],
#
#        ...,
#
#        [[ 95, 180, 176],
#         [ 94, 179, 175],
#         [ 95, 180, 176],
#         ...,
#         [ 87, 168, 165],
#         [ 92, 173, 170],
#         [ 97, 178, 175]],
#
#        [[ 94, 179, 175],
#         [ 96, 181, 177],
#         [ 99, 184, 180],
#         ...,
#         [ 85, 166, 163],
#         [ 89, 170, 167],
#         [ 94, 175, 172]],
#
#        [[ 94, 179, 175],
#         [ 98, 183, 179],
#         [102, 187, 183],
# ...

# %%
img.shape
# Out:
# (720, 1280, 3)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FF330C6FDD0>

# %%
# cv2.rectangle(img, (x,y), (w,h), (blue,green,red), borderThickness)
cv2.rectangle(img, (100,100), (200,200), (230,220,120),5)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FF330B290D0>

# %%
img = cv2.imread('img_2.jpg')

img = cv2.resize(img, (400,200))
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=400x200 at 0x7FF32A9CAB50>

# %%
img
# Out:
# array([[ 70,  72,  75, ...,  49,  48,  48],
#        [ 74,  76,  78, ...,  49,  50,  50],
#        [ 81,  82,  84, ...,  50,  50,  53],
#        ...,
#        [168, 168, 169, ..., 158, 158, 158],
#        [169, 167, 167, ..., 159, 165, 162],
#        [169, 173, 171, ..., 164, 163, 160]], dtype=uint8)

# %%
img.shape
# Out:
# (200, 400)

# %%
cv2.imwrite('new_img.jpg',img)
# Out:
# True

# %%
from skimage import io

# %%
url = "https://img.etimg.com/thumb/msid-87844232,width-650,imgsize-27324,,resizemode-4,quality-100/ms-dhoni.jpg"
img = io.imread(url)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=650x488 at 0x7FF32049D5D0>

# %%
import urllib.request as url

# %%
path = "https://img.etimg.com/thumb/msid-87844232,width-650,imgsize-27324,,resizemode-4,quality-100/ms-dhoni.jpg"
url.urlretrieve(path,'dhoni.jpg')
# Out:
# ('dhoni.jpg', <http.client.HTTPMessage at 0x7ff31ffbac10>)

# %%
dhoni_img = cv2.imread('dhoni.jpg')
